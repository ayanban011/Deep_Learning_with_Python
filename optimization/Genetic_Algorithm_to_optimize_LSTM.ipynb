# %% [markdown]
# <a href="https://colab.research.google.com/github/ayanbabusona/DeepLearning/blob/main/Genetic_Algorithm_to_optimize_LSTM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Use of Genetic Algorithm to optimize **LSTM**

# %% [markdown]
# To begin with let us first implement the genetic algorithm step by step and solve a basic problem with it and then we will optimize LSTM using this implemented Genetic Algorithm.

# %% [markdown]
# ## Guess the Word
# Here the genetic algorithms will be used to guess a word. The genetic algorithm will know the number of letters in the word and will guess those letters until it finds the right answer. It has been decided to represent the genes as a single alphanumeric character; strings of these characters thus constitute a chromosome. And our fitness function is the sum of the characters matching in the individual and the right word.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#dependency installation
# !pip install deap
# Out:
# Requirement already satisfied: deap in /usr/local/lib/python3.6/dist-packages (1.3.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from deap) (1.18.5)

# %% [markdown]
# As the first step, The modules are imported. The string module and the random module would be used to generate random characters from (a—z, A—Z, and 0—9). From the DEAP module, creator, base, and tools are essentially needed to implement this algorithm.

# %%
import string
import random
from deap import base, creator, tools

# %% [markdown]
# Let's create a class which inherits the deap.base module and define the type of optimization (i.e. maximization, minimization). Maximization represents with +1.0 and minimization represent with -1.0.

# %%
creator.create("FitnessMax", base.Fitness, weights=(1.0,))
# Out:
# /usr/local/lib/python3.6/dist-packages/deap/creator.py:141: RuntimeWarning: A class named 'FitnessMax' has already been created and it will be overwritten. Consider deleting previous creation of that class or rename it.
#   RuntimeWarning)

# %% [markdown]
# We also define an Individual class, which will inherit the class list, and tell the DEAP creator module to assign FitnessMax as its fitness attribute.

# %%
creator.create("Individual", list, fitness=creator.FitnessMax)
# Out:
# /usr/local/lib/python3.6/dist-packages/deap/creator.py:141: RuntimeWarning: A class named 'Individual' has already been created and it will be overwritten. Consider deleting previous creation of that class or rename it.
#   RuntimeWarning)

# %% [markdown]
# Now, with the Individual class defined, we use the toolbox of DEAP defined in the base module. We will use it to create a population and define our gene pool. All the objects that we will need from now onward—an individual, the population, the functions, the operators, and the arguments—are stored in a container called toolbox. We can add or remove content to/from the toolbox container using the register() and unregister() methods.

# %%
toolbox = base.Toolbox()
# Gene Pool
toolbox.register("attr_string", random.choice, \
               string.ascii_letters + string.digits )

# %% [markdown]
# Now that we have defined how the gene pool will be created, we create an individual and then a population by repeatedly using the Individual class. We will pass the class to the toolbox responsible for creating a N parameter , telling it how many genes to produce.

# %%
#Number of characters in word
# The word to be guessed
word = list('hello')
N = len(word)
# Initialize population
toolbox.register("individual", tools.initRepeat, \
         creator.Individual, toolbox.attr_string, N )
toolbox.register("population",tools.initRepeat, list,\
         toolbox.individual)

# %% [markdown]
# We define the fitness function. Note the comma in the return statement. This is because the fitness function in DEAP is returned as a tuple to allow multi-objective fitness functions.

# %%
def evalWord(individual, word):
    return sum(individual[i] == word[i] for i in\
            range(len(individual))),

# %% [markdown]
# Add the fitness function to the container. Also, add the crossover operator, mutation operator, and parent selector operator. You can see that, for this, we are using the register function. In the first statement, we register the fitness function that we have defined, along with the additional arguments it will take. The next statement registers the crossover operation; it specifies that here we are using a two-point crossover (cxTwoPoint). Next, we register the mutation operator; we choose the mutShuffleIndexes option, which shuffles the attributes of the input individual with a probability indpb=0.05. And finally, we define how the parents are selected; here, we have defined the method of selection as tournament selection with a tournament size of 3.

# %%
toolbox.register("evaluate", evalWord, word)
toolbox.register("mate", tools.cxTwoPoint)
toolbox.register("mutate", tools.mutShuffleIndexes, indpb=0.05)
toolbox.register("select", tools.selTournament, tournsize=3)

# %% [markdown]
# Now we have all the ingredients to cook off, so we will write down the code of the genetic algorithm, which will perform the steps we mentioned earlier in a repetitive manner.

# %%
def main():
    random.seed(64)
    # create an initial population of 300 individuals 
    pop = toolbox.population(n=300)
    # CXPB is the crossover probability 
    # MUTPB is the probability for mutating an individual
    CXPB, MUTPB = 0.5, 0.2
    print("Start of evolution")
    # Evaluate the entire population
    fitnesses = list(map(toolbox.evaluate, pop))
    for ind, fit in zip(pop, fitnesses):
        ind.fitness.values = fit

    print(" Evaluated %i individuals" % len(pop))

    # Extracting all the fitnesses of individuals in a list
    fits = [ind.fitness.values[0] for ind in pop]
    # Variable keeping track of the number of generations
    g = 0

    # Begin the evolution
    while max(fits) < 5 and g < 1000:
        # A new generation
        g += 1
        print("-- Generation %i --" % g)

        # Select the next generation individuals
        offspring = toolbox.select(pop, len(pop))
        # Clone the selected individuals
        offspring = list(map(toolbox.clone, offspring))

        # Apply crossover and mutation on the offspring
        for child1, child2 in zip(offspring[::2], offspring[1::2]):
            # cross two individuals with probability CXPB
            if random.random() < CXPB:
                toolbox.mate(child1, child2)
                # fitness values of the children
                # must be recalculated later
                del child1.fitness.values
                del child2.fitness.values
                for mutant in offspring:
                # mutate an individual with probability MUTPB
                    if random.random() < MUTPB:
                        toolbox.mutate(mutant)
                        del mutant.fitness.values

        # Evaluate the individuals with an invalid fitness
        invalid_ind = [ind for ind in offspring if not ind.fitness.valid]
        fitnesses = map(toolbox.evaluate, invalid_ind)
        for ind, fit in zip(invalid_ind, fitnesses):
            ind.fitness.values = fit

        print(" Evaluated %i individuals" % len(invalid_ind))

        # The population is entirely replaced by the offspring
        pop[:] = offspring

        # Gather all the fitnesses in one list and print the stats
        fits = [ind.fitness.values[0] for ind in pop]

        length = len(pop)
        mean = sum(fits) / length
        sum2 = sum(x*x for x in fits)
        std = abs(sum2 / length - mean**2)**0.5

        print(" Min %s" % min(fits))
        print(" Max %s" % max(fits))
        print(" Avg %s" % mean)
        print(" Std %s" % std)

    print("-- End of (successful) evolution --")

    best_ind = tools.selBest(pop, 1)[0]
    print("Best individual is %s, %s" % (''.join(best_ind),\
    best_ind.fitness.values))

# %%
#Evaluate the Result
main()
# Out:
# Streaming output truncated to the last 5000 lines.
# -- Generation 168 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.94
#  Std 0.7635880215578731
# -- Generation 169 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.78
#  Std 0.7516204716034105
# -- Generation 170 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.7766666666666666
#  Std 0.7484131360566987
# -- Generation 171 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.91
#  Std 0.689371694612807
# -- Generation 172 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.9366666666666668
#  Std 0.7206401475231735
# -- Generation 173 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.8966666666666667
#  Std 0.7066273573972509
# -- Generation 174 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.9266666666666667
#  Std 0.6889283142840201
# -- Generation 175 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.8766666666666667
#  Std 0.6890492644861386
# -- Generation 176 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.8566666666666667
#  Std 0.71376155371073
# -- Generation 177 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.8466666666666667
#  Std 0.6805553287981483
# -- Generation 178 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.8566666666666667
#  Std 0.7457360271719623
# -- Generation 179 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.9833333333333334
#  Std 0.6853628398317361
# -- Generation 180 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.9733333333333334
#  Std 0.7113055289786208
# -- Generation 181 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.94
#  Std 0.6902173570694962
# -- Generation 182 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 2.0033333333333334
#  Std 0.7094520577334467
# -- Generation 183 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.9533333333333334
#  Std 0.696052360737961
# -- Generation 184 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.9233333333333333
#  Std 0.7510807028690211
# -- Generation 185 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.99
#  Std 0.7187257242277241
# -- Generation 186 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.9266666666666667
#  Std 0.7624230380103214
# -- Generation 187 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.88
#  Std 0.7016171795692197
# -- Generation 188 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.8466666666666667
#  Std 0.7459818287926918
# -- Generation 189 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.86
#  Std 0.7073895673530954
# -- Generation 190 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.9966666666666666
#  Std 0.7094520577334473
# -- Generation 191 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.9033333333333333
#  Std 0.7307454337105971
# -- Generation 192 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.8933333333333333
#  Std 0.6747509828735999
# -- Generation 193 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.9133333333333333
#  Std 0.7297183627187197
# -- Generation 194 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.98
#  Std 0.6877014856268188
# -- Generation 195 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.8766666666666667
#  Std 0.7312926150925418
# -- Generation 196 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.84
#  Std 0.6935896961941307
# -- Generation 197 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.84
#  Std 0.6332982446420221
# -- Generation 198 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.8966666666666667
#  Std 0.6971290331702508
# -- Generation 199 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.9766666666666666
#  Std 0.6553285859441477
# -- Generation 200 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.86
#  Std 0.702661606559895
# -- Generation 201 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.93
#  Std 0.6151693533762338
# -- Generation 202 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.9233333333333333
#  Std 0.6614042300708061
# -- Generation 203 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.9033333333333333
#  Std 0.6223521689704489
# -- Generation 204 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.9166666666666667
#  Std 0.6504272100362616
# -- Generation 205 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.9633333333333334
#  Std 0.6698175539320806
# -- Generation 206 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.9233333333333333
#  Std 0.6409281464321015
# -- Generation 207 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.9433333333333334
#  Std 0.6684226872936682
# -- Generation 208 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.9233333333333333
#  Std 0.6909815884345658
# -- Generation 209 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.9433333333333334
#  Std 0.6733910866320966
# -- Generation 210 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.9466666666666668
#  Std 0.695573304707866
# -- Generation 211 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.91
#  Std 0.7084490101623409
# -- Generation 212 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.89
#  Std 0.7008803987367129
# -- Generation 213 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.8933333333333333
#  Std 0.6747509828735999
# -- Generation 214 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.8433333333333333
#  Std 0.6871115063963218
# -- Generation 215 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.8933333333333333
#  Std 0.6894119877757339
# -- Generation 216 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.8766666666666667
#  Std 0.722118796013201
# -- Generation 217 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.9
#  Std 0.7280109889280517
# -- Generation 218 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.96
#  Std 0.6721111019268565
# -- Generation 219 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.96
#  Std 0.7106804251326098
# -- Generation 220 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 2.0
#  Std 0.748331477354788
# -- Generation 221 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.9533333333333334
#  Std 0.7288041956215369
# -- Generation 222 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.92
#  Std 0.7573638491504594
# -- Generation 223 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.9166666666666667
#  Std 0.7139483330201296
# -- Generation 224 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.79
#  Std 0.7522632517942107
# -- Generation 225 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.8566666666666667
#  Std 0.7043594410684236
# -- Generation 226 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.8966666666666667
#  Std 0.7298325530938966
# -- Generation 227 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.9533333333333334
#  Std 0.7513247559403913
# -- Generation 228 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.8866666666666667
#  Std 0.7214491589078811
# -- Generation 229 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.86
#  Std 0.761839878189636
# -- Generation 230 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.9033333333333333
#  Std 0.7307454337105971
# -- Generation 231 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.88
#  Std 0.7203702751594724
# -- Generation 232 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.8666666666666667
#  Std 0.7086763875156432
# -- Generation 233 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.78
#  Std 0.6915682660928467
# -- Generation 234 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.8833333333333333
#  Std 0.6295942255841369
# -- Generation 235 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.8966666666666667
#  Std 0.6826337882707602
# -- Generation 236 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.8433333333333333
#  Std 0.6919457268376538
# -- Generation 237 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.9733333333333334
#  Std 0.6212532137184928
# -- Generation 238 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.8533333333333333
#  Std 0.6771180760317134
# -- Generation 239 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.9866666666666666
#  Std 0.682999918659504
# -- Generation 240 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.8833333333333333
#  Std 0.7045487129282749
# -- Generation 241 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.79
#  Std 0.7112664760833313
# -- Generation 242 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.83
#  Std 0.6741167060185742
# -- Generation 243 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 2.0033333333333334
#  Std 0.6806777668046913
# -- Generation 244 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 2.013333333333333
#  Std 0.6974875546480304
# -- Generation 245 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.8866666666666667
#  Std 0.748658058721663
# -- Generation 246 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.8466666666666667
#  Std 0.6706878724281676
# -- Generation 247 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.88
#  Std 0.6920500945259194
# -- Generation 248 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.9566666666666668
#  Std 0.64404106149289
# -- Generation 249 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.9
#  Std 0.6557438524302002
# -- Generation 250 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.8666666666666667
#  Std 0.7039570693980957
# -- Generation 251 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.8733333333333333
#  Std 0.6355749802781384
# -- Generation 252 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.9333333333333333
#  Std 0.6128258770283412
# -- Generation 253 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.99
#  Std 0.568536131950585
# -- Generation 254 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.9633333333333334
#  Std 0.6180524968713326
# -- Generation 255 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.9433333333333334
#  Std 0.6111101010092663
# -- Generation 256 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.9433333333333334
#  Std 0.5831999847584202
# -- Generation 257 --
#  Evaluated 300 individuals
#  Min 1.0
#  Max 3.0
#  Avg 2.0033333333333334
#  Std 0.6027621605759789
# -- Generation 258 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.8733333333333333
#  Std 0.6662998991111703
# -- Generation 259 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.91
#  Std 0.689371694612807
# -- Generation 260 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.9066666666666667
#  Std 0.6865048352989865
# -- Generation 261 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.9033333333333333
#  Std 0.6587783306157611
# -- Generation 262 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.91
#  Std 0.6796322535018482
# -- Generation 263 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.9333333333333333
#  Std 0.6599663291074441
# -- Generation 264 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.9266666666666667
#  Std 0.7127100080366171
# -- Generation 265 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 2.026666666666667
#  Std 0.7113055289786201
# -- Generation 266 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.9133333333333333
#  Std 0.672672943479139
# -- Generation 267 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.9366666666666668
#  Std 0.6777331497147102
# -- Generation 268 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.9466666666666668
#  Std 0.6661998365522329
# -- Generation 269 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.9366666666666668
#  Std 0.6971290331702504
# -- Generation 270 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.9366666666666668
#  Std 0.7252509144350583
# -- Generation 271 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.9833333333333334
#  Std 0.6998015591739001
# -- Generation 272 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.92
#  Std 0.7529497548530931
# -- Generation 273 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.94
#  Std 0.7186097689288675
# -- Generation 274 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.8266666666666667
#  Std 0.7047142841054255
# -- Generation 275 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.95
#  Std 0.7262919523166977
# -- Generation 276 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.88
#  Std 0.6920500945259194
# -- Generation 277 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.8966666666666667
#  Std 0.7206401475231738
# -- Generation 278 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.9233333333333333
#  Std 0.7421515269059877
# -- Generation 279 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.89
#  Std 0.7008803987367129
# -- Generation 280 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.9133333333333333
#  Std 0.7297183627187197
# -- Generation 281 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.8466666666666667
#  Std 0.7851680641040417
# -- Generation 282 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.92
#  Std 0.6930127463955241
# -- Generation 283 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.8866666666666667
#  Std 0.7351794943337909
# -- Generation 284 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.8866666666666667
#  Std 0.7121485487983216
# -- Generation 285 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.8733333333333333
#  Std 0.7465178423111459
# -- Generation 286 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.9533333333333334
#  Std 0.7423985153241855
# -- Generation 287 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.9033333333333333
#  Std 0.6932932680731552
# -- Generation 288 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.84
#  Std 0.6887670143089024
# -- Generation 289 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.8866666666666667
#  Std 0.7074523933727899
# -- Generation 290 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.9266666666666667
#  Std 0.7266055020129942
# -- Generation 291 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.8833333333333333
#  Std 0.6853628398317364
# -- Generation 292 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.9033333333333333
#  Std 0.7443042985828371
# -- Generation 293 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.9066666666666667
#  Std 0.7243080989621905
# -- Generation 294 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.9333333333333333
#  Std 0.7226494462892933
# -- Generation 295 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.9
#  Std 0.7724420150837648
# -- Generation 296 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.9733333333333334
#  Std 0.7252279335185284
# -- Generation 297 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.9233333333333333
#  Std 0.7510807028690211
# -- Generation 298 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.9666666666666666
#  Std 0.7564537145273482
# -- Generation 299 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.8866666666666667
#  Std 0.7121485487983216
# -- Generation 300 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.8433333333333333
#  Std 0.66241141965465
# -- Generation 301 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.9066666666666667
#  Std 0.7103676669318656
# -- Generation 302 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.9166666666666667
#  Std 0.7045487129282746
# -- Generation 303 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.9266666666666667
#  Std 0.7402402012560213
# -- Generation 304 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.93
#  Std 0.7692637172430964
# -- Generation 305 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.79
#  Std 0.7610738028163453
# -- Generation 306 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.8833333333333333
#  Std 0.7414325473178409
# -- Generation 307 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.84
#  Std 0.7709734106958552
# -- Generation 308 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.9533333333333334
#  Std 0.696052360737961
# -- Generation 309 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.9533333333333334
#  Std 0.7860166806259409
# -- Generation 310 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.9133333333333333
#  Std 0.752211554166926
# -- Generation 311 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.8433333333333333
#  Std 0.7202700110992328
# -- Generation 312 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.8666666666666667
#  Std 0.7673909622147557
# -- Generation 313 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.91
#  Std 0.7801068302909974
# -- Generation 314 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.83
#  Std 0.7446028023942247
# -- Generation 315 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.9133333333333333
#  Std 0.807767843435779
# -- Generation 316 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.8866666666666667
#  Std 0.7530973081584849
# -- Generation 317 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.8933333333333333
#  Std 0.7451770855903238
# -- Generation 318 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.9533333333333334
#  Std 0.7008249107698408
# -- Generation 319 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.88
#  Std 0.6774461848245463
# -- Generation 320 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.9566666666666668
#  Std 0.669419317186337
# -- Generation 321 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.9566666666666668
#  Std 0.6793052005951046
# -- Generation 322 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.9066666666666667
#  Std 0.6913432979031152
# -- Generation 323 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 2.006666666666667
#  Std 0.6531632431653064
# -- Generation 324 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.8433333333333333
#  Std 0.6919457268376538
# -- Generation 325 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.9
#  Std 0.6855654600401045
# -- Generation 326 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.92
#  Std 0.6685307272918231
# -- Generation 327 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.9633333333333334
#  Std 0.6845842209367342
# -- Generation 328 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.9233333333333333
#  Std 0.6714081388312845
# -- Generation 329 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.9066666666666667
#  Std 0.6413180871368661
# -- Generation 330 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.8966666666666667
#  Std 0.6526782430025448
# -- Generation 331 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.9233333333333333
#  Std 0.6812651629301341
# -- Generation 332 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.93
#  Std 0.6770770512529085
# -- Generation 333 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.97
#  Std 0.7041069994444501
# -- Generation 334 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.8933333333333333
#  Std 0.6894119877757339
# -- Generation 335 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.8966666666666667
#  Std 0.6923310062551169
# -- Generation 336 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.9033333333333333
#  Std 0.7307454337105971
# -- Generation 337 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.87
#  Std 0.7701298591796057
# -- Generation 338 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.8533333333333333
#  Std 0.7948724565754068
# -- Generation 339 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.78
#  Std 0.7291090453423275
# -- Generation 340 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.92
#  Std 0.6930127463955241
# -- Generation 341 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.9266666666666667
#  Std 0.7127100080366171
# -- Generation 342 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.8933333333333333
#  Std 0.7316343956436775
# -- Generation 343 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.93
#  Std 0.7383088784512887
# -- Generation 344 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.9366666666666668
#  Std 0.7206401475231735
# -- Generation 345 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.9533333333333334
#  Std 0.7468749709437462
# -- Generation 346 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.8766666666666667
#  Std 0.7581483290813801
# -- Generation 347 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.9
#  Std 0.6952217871538073
# -- Generation 348 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.8833333333333333
#  Std 0.6902093080282887
# -- Generation 349 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.86
#  Std 0.6785278181474946
# -- Generation 350 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.8733333333333333
#  Std 0.651118695443124
# -- Generation 351 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.9166666666666667
#  Std 0.6452820227535309
# -- Generation 352 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.8866666666666667
#  Std 0.6535713852025314
# -- Generation 353 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.9533333333333334
#  Std 0.6254243004197676
# -- Generation 354 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.9
#  Std 0.6952217871538073
# -- Generation 355 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.9233333333333333
#  Std 0.6812651629301341
# -- Generation 356 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.95
#  Std 0.6383572667401853
# -- Generation 357 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.9466666666666668
#  Std 0.635470079722265
# -- Generation 358 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.9033333333333333
#  Std 0.6382180052475976
# -- Generation 359 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.9666666666666666
#  Std 0.636832439151427
# -- Generation 360 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.86
#  Std 0.663626400921482
# -- Generation 361 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.9733333333333334
#  Std 0.6526527066944221
# -- Generation 362 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.99
#  Std 0.6707458535093601
# -- Generation 363 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.9666666666666666
#  Std 0.6624868971450598
# -- Generation 364 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.9533333333333334
#  Std 0.6515281182641997
# -- Generation 365 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.9266666666666667
#  Std 0.6840727706578846
# -- Generation 366 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.9433333333333334
#  Std 0.6634170801405569
# -- Generation 367 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.9266666666666667
#  Std 0.7311786527396859
# -- Generation 368 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.9333333333333333
#  Std 0.7318166133366718
# -- Generation 369 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.9266666666666667
#  Std 0.7402402012560213
# -- Generation 370 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.93
#  Std 0.7153786875960637
# -- Generation 371 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.9566666666666668
#  Std 0.722118796013201
# -- Generation 372 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 2.0033333333333334
#  Std 0.7141350634781131
# -- Generation 373 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.89
#  Std 0.7150058274820795
# -- Generation 374 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.8733333333333333
#  Std 0.7329999242079698
# -- Generation 375 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.8466666666666667
#  Std 0.7278888804084194
# -- Generation 376 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.8533333333333333
#  Std 0.696531087285812
# -- Generation 377 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.94
#  Std 0.7045565981523414
# -- Generation 378 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.94
#  Std 0.723233480050991
# -- Generation 379 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.9066666666666667
#  Std 0.7288956639251527
# -- Generation 380 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.9533333333333334
#  Std 0.7557483414176676
# -- Generation 381 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.9066666666666667
#  Std 0.7379852452605146
# -- Generation 382 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.9366666666666668
#  Std 0.7252509144350583
# -- Generation 383 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.8666666666666667
#  Std 0.736357401145817
# -- Generation 384 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 2.03
#  Std 0.7227954989714135
# -- Generation 385 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.9833333333333334
#  Std 0.7722621892135396
# -- Generation 386 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.95
#  Std 0.735413715763674
# -- Generation 387 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.8633333333333333
#  Std 0.7334772586037615
# -- Generation 388 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.91
#  Std 0.6546500337330375
# -- Generation 389 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.9433333333333334
#  Std 0.711891065324526
# -- Generation 390 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.86
#  Std 0.7441326046702518
# -- Generation 391 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.9033333333333333
#  Std 0.7750197130109375
# -- Generation 392 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.9266666666666667
#  Std 0.7220033856491869
# -- Generation 393 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.82
#  Std 0.8047359815492282
# -- Generation 394 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.86
#  Std 0.761839878189636
# -- Generation 395 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.83
#  Std 0.7355949972641193
# -- Generation 396 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.9066666666666667
#  Std 0.7334545354386699
# -- Generation 397 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.9
#  Std 0.6757711644237764
# -- Generation 398 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.8966666666666667
#  Std 0.6777331497147105
# -- Generation 399 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.9966666666666666
#  Std 0.6855573563815718
# -- Generation 400 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.9866666666666666
#  Std 0.7022503510540642
# -- Generation 401 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.8866666666666667
#  Std 0.702724855275678
# -- Generation 402 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.8666666666666667
#  Std 0.7039570693980957
# -- Generation 403 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.89
#  Std 0.661740130262628
# -- Generation 404 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.92
#  Std 0.6685307272918231
# -- Generation 405 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.8566666666666667
#  Std 0.6996110030263641
# -- Generation 406 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.9433333333333334
#  Std 0.6783230957458412
# -- Generation 407 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.87
#  Std 0.725557257101969
# -- Generation 408 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.8833333333333333
#  Std 0.7369230323144715
# -- Generation 409 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.96
#  Std 0.701237002256251
# -- Generation 410 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.9733333333333334
#  Std 0.6971051251823895
# -- Generation 411 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.9733333333333334
#  Std 0.7654773383683906
# -- Generation 412 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.9466666666666668
#  Std 0.7237556370918447
# -- Generation 413 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.7866666666666666
#  Std 0.6936537721050434
# -- Generation 414 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.86
#  Std 0.6483826030978926
# -- Generation 415 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.8866666666666667
#  Std 0.6785933162718952
# -- Generation 416 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 2.006666666666667
#  Std 0.6271274901396748
# -- Generation 417 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.93
#  Std 0.7246378405796927
# -- Generation 418 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.9466666666666668
#  Std 0.7144850515503374
# -- Generation 419 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.9066666666666667
#  Std 0.7056596598612931
# -- Generation 420 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.9266666666666667
#  Std 0.6791825151525089
# -- Generation 421 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.91
#  Std 0.7451398079107928
# -- Generation 422 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.8733333333333333
#  Std 0.7509697434354834
# -- Generation 423 --
#  Evaluated 300 individuals
#  Min 1.0
#  Max 3.0
#  Avg 1.9633333333333334
#  Std 0.7085117422378323
# -- Generation 424 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.93
#  Std 0.7246378405796927
# -- Generation 425 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.87
#  Std 0.7209484493822468
# -- Generation 426 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.89
#  Std 0.7150058274820795
# -- Generation 427 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.8866666666666667
#  Std 0.7214491589078811
# -- Generation 428 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.9266666666666667
#  Std 0.7127100080366171
# -- Generation 429 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.86
#  Std 0.7259935720560247
# -- Generation 430 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.8733333333333333
#  Std 0.7420392322662072
# -- Generation 431 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.8266666666666667
#  Std 0.7325450308494504
# -- Generation 432 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.8433333333333333
#  Std 0.7607817616694613
# -- Generation 433 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.83
#  Std 0.7923172765165898
# -- Generation 434 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.9033333333333333
#  Std 0.7075701771241885
# -- Generation 435 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.8866666666666667
#  Std 0.7074523933727899
# -- Generation 436 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.84
#  Std 0.6691287868066456
# -- Generation 437 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.8766666666666667
#  Std 0.7537388289203507
# -- Generation 438 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.8933333333333333
#  Std 0.6894119877757339
# -- Generation 439 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.83
#  Std 0.7264755100254007
# -- Generation 440 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.9033333333333333
#  Std 0.7443042985828371
# -- Generation 441 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.8933333333333333
#  Std 0.7672171936435093
# -- Generation 442 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 2.01
#  Std 0.7046748659251784
# -- Generation 443 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.86
#  Std 0.7441326046702518
# -- Generation 444 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.93
#  Std 0.7692637172430964
# -- Generation 445 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.9133333333333333
#  Std 0.7158832927851358
# -- Generation 446 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.8533333333333333
#  Std 0.7107429602574729
# -- Generation 447 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.93
#  Std 0.696491205974634
# -- Generation 448 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.94
#  Std 0.723233480050991
# -- Generation 449 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.9166666666666667
#  Std 0.7592027982620246
# -- Generation 450 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.8633333333333333
#  Std 0.7197144495484925
# -- Generation 451 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.87
#  Std 0.7301369734508723
# -- Generation 452 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.8833333333333333
#  Std 0.6902093080282887
# -- Generation 453 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.8166666666666667
#  Std 0.7635807459303539
# -- Generation 454 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.7433333333333334
#  Std 0.7146949621264225
# -- Generation 455 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.87
#  Std 0.6681566682547835
# -- Generation 456 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.92
#  Std 0.6482797749943049
# -- Generation 457 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.9466666666666668
#  Std 0.6761327943204319
# -- Generation 458 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.9533333333333334
#  Std 0.6766256145182667
# -- Generation 459 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.94
#  Std 0.670621602197046
# -- Generation 460 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.9166666666666667
#  Std 0.6804818554197865
# -- Generation 461 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.9166666666666667
#  Std 0.6504272100362616
# -- Generation 462 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.93
#  Std 0.696491205974634
# -- Generation 463 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.91
#  Std 0.7406528651579405
# -- Generation 464 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.95
#  Std 0.6982120021884473
# -- Generation 465 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.9233333333333333
#  Std 0.746629463358871
# -- Generation 466 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.9233333333333333
#  Std 0.6909815884345658
# -- Generation 467 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.8166666666666667
#  Std 0.7369230323144715
# -- Generation 468 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.9666666666666666
#  Std 0.7063206700139029
# -- Generation 469 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.9666666666666666
#  Std 0.7340905181848413
# -- Generation 470 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.9
#  Std 0.7234178138070239
# -- Generation 471 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.9333333333333333
#  Std 0.7760297817881877
# -- Generation 472 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.9533333333333334
#  Std 0.8028006532688478
# -- Generation 473 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.9366666666666668
#  Std 0.7953964769569674
# -- Generation 474 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.8433333333333333
#  Std 0.7651506750670457
# -- Generation 475 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.8366666666666667
#  Std 0.7979069842754577
# -- Generation 476 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.93
#  Std 0.7428099801878449
# -- Generation 477 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.8433333333333333
#  Std 0.8157545927272221
# -- Generation 478 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.8766666666666667
#  Std 0.82550321353436
# -- Generation 479 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.86
#  Std 0.7791448303535524
# -- Generation 480 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.8833333333333333
#  Std 0.7369230323144715
# -- Generation 481 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.8033333333333332
#  Std 0.7469865386262922
# -- Generation 482 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.86
#  Std 0.7351190379795639
# -- Generation 483 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.93
#  Std 0.7383088784512887
# -- Generation 484 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.8733333333333333
#  Std 0.8469290931883785
# -- Generation 485 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.8566666666666667
#  Std 0.7975727065429344
# -- Generation 486 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.8266666666666667
#  Std 0.7549540089009101
# -- Generation 487 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.8033333333333332
#  Std 0.7775960105064554
# -- Generation 488 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.87
#  Std 0.752617654146734
# -- Generation 489 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.9166666666666667
#  Std 0.7139483330201296
# -- Generation 490 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.8466666666666667
#  Std 0.754865698135915
# -- Generation 491 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.8366666666666667
#  Std 0.7325677822260244
# -- Generation 492 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.8766666666666667
#  Std 0.722118796013201
# -- Generation 493 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.87
#  Std 0.7301369734508723
# -- Generation 494 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.8866666666666667
#  Std 0.6736632854937418
# -- Generation 495 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.81
#  Std 0.6433506042586732
# -- Generation 496 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.9266666666666667
#  Std 0.7080175766807545
# -- Generation 497 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.86
#  Std 0.7167519329121707
# -- Generation 498 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.9033333333333333
#  Std 0.6836097002107432
# -- Generation 499 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.9933333333333334
#  Std 0.6732673234970555
# -- Generation 500 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.9066666666666667
#  Std 0.7056596598612931
# -- Generation 501 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.9066666666666667
#  Std 0.6961481323843527
# -- Generation 502 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.8966666666666667
#  Std 0.7018942623754346
# -- Generation 503 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.9266666666666667
#  Std 0.6937498748748633
# -- Generation 504 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.9033333333333333
#  Std 0.6485796447280436
# -- Generation 505 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.9033333333333333
#  Std 0.7122655559706802
# -- Generation 506 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.91
#  Std 0.7177975573470093
# -- Generation 507 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.9633333333333334
#  Std 0.7085117422378323
# -- Generation 508 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.9466666666666668
#  Std 0.6141299174894148
# -- Generation 509 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.9333333333333333
#  Std 0.6182412330330471
# -- Generation 510 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.9433333333333334
#  Std 0.6583734165012703
# -- Generation 511 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.9866666666666666
#  Std 0.6530611678004512
# -- Generation 512 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.9466666666666668
#  Std 0.6761327943204319
# -- Generation 513 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.9666666666666666
#  Std 0.7295356209413101
# -- Generation 514 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.9733333333333334
#  Std 0.6874752520798267
# -- Generation 515 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.96
#  Std 0.6671331701142339
# -- Generation 516 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.8866666666666667
#  Std 0.7260547882601944
# -- Generation 517 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 2.0
#  Std 0.7071067811865476
# -- Generation 518 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.8166666666666667
#  Std 0.7092640943651072
# -- Generation 519 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.91
#  Std 0.7177975573470093
# -- Generation 520 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.8566666666666667
#  Std 0.7322036753678735
# -- Generation 521 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.82
#  Std 0.7399999999999998
# -- Generation 522 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.8566666666666667
#  Std 0.7184164685071064
# -- Generation 523 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.94
#  Std 0.7139561144309456
# -- Generation 524 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.8966666666666667
#  Std 0.7018942623754346
# -- Generation 525 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.9066666666666667
#  Std 0.7009200303093707
# -- Generation 526 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.9333333333333333
#  Std 0.6749485577105531
# -- Generation 527 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.86
#  Std 0.7305705532892307
# -- Generation 528 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.8866666666666667
#  Std 0.7260547882601944
# -- Generation 529 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.88
#  Std 0.6920500945259194
# -- Generation 530 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.8833333333333333
#  Std 0.7635807459303539
# -- Generation 531 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.8866666666666667
#  Std 0.748658058721663
# -- Generation 532 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.8566666666666667
#  Std 0.7806763449442767
# -- Generation 533 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.8466666666666667
#  Std 0.7093345864650586
# -- Generation 534 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.89
#  Std 0.6961082291329896
# -- Generation 535 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.83
#  Std 0.7031595361888601
# -- Generation 536 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.9033333333333333
#  Std 0.7122655559706802
# -- Generation 537 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.8766666666666667
#  Std 0.7403527687678504
# -- Generation 538 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.8666666666666667
#  Std 0.7133644853010896
# -- Generation 539 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.84
#  Std 0.6740919818541085
# -- Generation 540 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.9433333333333334
#  Std 0.6733910866320966
# -- Generation 541 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.9933333333333334
#  Std 0.668298004053747
# -- Generation 542 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.9766666666666666
#  Std 0.7501925678710027
# -- Generation 543 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.9433333333333334
#  Std 0.711891065324526
# -- Generation 544 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.8766666666666667
#  Std 0.7174879015627295
# -- Generation 545 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.92
#  Std 0.7440430095095312
# -- Generation 546 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.92
#  Std 0.7166589146867569
# -- Generation 547 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.8466666666666667
#  Std 0.6606730574867489
# -- Generation 548 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.93
#  Std 0.6259126669645426
# -- Generation 549 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.8833333333333333
#  Std 0.655532014643238
# -- Generation 550 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.93
#  Std 0.6416904757487576
# -- Generation 551 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.9066666666666667
#  Std 0.6961481323843527
# -- Generation 552 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.9566666666666668
#  Std 0.6491960840574712
# -- Generation 553 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.9066666666666667
#  Std 0.7056596598612931
# -- Generation 554 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.8733333333333333
#  Std 0.6811428305102798
# -- Generation 555 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.8933333333333333
#  Std 0.684559874826317
# -- Generation 556 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.8633333333333333
#  Std 0.6961720732373253
# -- Generation 557 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.92
#  Std 0.739549412367648
# -- Generation 558 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.9533333333333334
#  Std 0.7688664094337553
# -- Generation 559 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.89
#  Std 0.870574522944475
# -- Generation 560 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.8833333333333333
#  Std 0.7592027982620249
# -- Generation 561 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.84
#  Std 0.8006663891201292
# -- Generation 562 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.9
#  Std 0.8266397845091495
# -- Generation 563 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.93
#  Std 0.7821551423257838
# -- Generation 564 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.94
#  Std 0.6853709457901856
# -- Generation 565 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.8866666666666667
#  Std 0.6979652968132125
# -- Generation 566 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.94
#  Std 0.7186097689288675
# -- Generation 567 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.9333333333333333
#  Std 0.7133644853010902
# -- Generation 568 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.9133333333333333
#  Std 0.7697329984409456
# -- Generation 569 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.88
#  Std 0.7739078325830111
# -- Generation 570 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.9966666666666666
#  Std 0.7280033577456144
# -- Generation 571 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.9
#  Std 0.7416198487095664
# -- Generation 572 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.9333333333333333
#  Std 0.7760297817881877
# -- Generation 573 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.8866666666666667
#  Std 0.8127046750750784
# -- Generation 574 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.8933333333333333
#  Std 0.784403524271079
# -- Generation 575 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.8633333333333333
#  Std 0.7514356629516304
# -- Generation 576 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.79
#  Std 0.7297716537840223
# -- Generation 577 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.94
#  Std 0.6755738301621814
# -- Generation 578 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.8566666666666667
#  Std 0.7043594410684236
# -- Generation 579 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.9366666666666668
#  Std 0.6727968159523015
# -- Generation 580 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.9033333333333333
#  Std 0.6836097002107432
# -- Generation 581 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.9
#  Std 0.7141428428542852
# -- Generation 582 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.9366666666666668
#  Std 0.6526782430025445
# -- Generation 583 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.95
#  Std 0.7076957915187386
# -- Generation 584 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.96
#  Std 0.6916646586316237
# -- Generation 585 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.9
#  Std 0.7371114795831994
# -- Generation 586 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 2.02
#  Std 0.6680319353643704
# -- Generation 587 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.9033333333333333
#  Std 0.7487693607216818
# -- Generation 588 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.9566666666666668
#  Std 0.7267201815157067
# -- Generation 589 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.94
#  Std 0.670621602197046
# -- Generation 590 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.9166666666666667
#  Std 0.7092640943651068
# -- Generation 591 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.9033333333333333
#  Std 0.7075701771241885
# -- Generation 592 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.96
#  Std 0.7246148402197312
# -- Generation 593 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.94
#  Std 0.741440040281973
# -- Generation 594 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.8366666666666667
#  Std 0.7460935300319631
# -- Generation 595 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.8233333333333333
#  Std 0.7202700110992328
# -- Generation 596 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.9533333333333334
#  Std 0.6666999991667081
# -- Generation 597 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.93
#  Std 0.7153786875960637
# -- Generation 598 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.8966666666666667
#  Std 0.7434080679919716
# -- Generation 599 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.81
#  Std 0.7352323895658208
# -- Generation 600 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.9333333333333333
#  Std 0.703957069398096
# -- Generation 601 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.8933333333333333
#  Std 0.7584780081774878
# -- Generation 602 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.8733333333333333
#  Std 0.7192279811637537
# -- Generation 603 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.9233333333333333
#  Std 0.7100156492798043
# -- Generation 604 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.9266666666666667
#  Std 0.7080175766807545
# -- Generation 605 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.88
#  Std 0.7608766873372672
# -- Generation 606 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
# ...
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.9
#  Std 0.6191391873668903
# -- Generation 856 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.9233333333333333
#  Std 0.695788920738339
# -- Generation 857 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.8633333333333333
#  Std 0.7334772586037615
# -- Generation 858 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.91
#  Std 0.7084490101623409
# -- Generation 859 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.9066666666666667
#  Std 0.6667999866693327
# -- Generation 860 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.96
#  Std 0.696467276091754
# -- Generation 861 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.8566666666666667
#  Std 0.7322036753678735
# -- Generation 862 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.93
#  Std 0.6770770512529085
# -- Generation 863 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.9266666666666667
#  Std 0.6742567924924613
# -- Generation 864 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.8733333333333333
#  Std 0.7004443034404824
# -- Generation 865 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.85
#  Std 0.7577378614446201
# -- Generation 866 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.7833333333333334
#  Std 0.7679337355672181
# -- Generation 867 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.8666666666666667
#  Std 0.6944222218666553
# -- Generation 868 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.8966666666666667
#  Std 0.6577655779649432
# -- Generation 869 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.85
#  Std 0.7444237144709095
# -- Generation 870 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.9233333333333333
#  Std 0.7053052924482811
# -- Generation 871 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.9333333333333333
#  Std 0.7086763875156435
# -- Generation 872 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.9466666666666668
#  Std 0.7237556370918447
# -- Generation 873 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.98
#  Std 0.6630233781700313
# -- Generation 874 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.96
#  Std 0.696467276091754
# -- Generation 875 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.97
#  Std 0.754387168501692
# -- Generation 876 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.8566666666666667
#  Std 0.7677600898428857
# -- Generation 877 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.88
#  Std 0.7249827584156742
# -- Generation 878 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.8833333333333333
#  Std 0.6950219820664351
# -- Generation 879 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.8466666666666667
#  Std 0.7278888804084194
# -- Generation 880 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.8833333333333333
#  Std 0.6804818554197868
# -- Generation 881 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.9433333333333334
#  Std 0.6733910866320966
# -- Generation 882 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.86
#  Std 0.6686304410260322
# -- Generation 883 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.9766666666666666
#  Std 0.6603955043928017
# -- Generation 884 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.8666666666666667
#  Std 0.7039570693980957
# -- Generation 885 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.9
#  Std 0.7187952884282611
# -- Generation 886 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.9166666666666667
#  Std 0.7045487129282746
# -- Generation 887 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.9533333333333334
#  Std 0.7288041956215369
# -- Generation 888 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.9166666666666667
#  Std 0.750370278966028
# -- Generation 889 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.94
#  Std 0.7503776826816395
# -- Generation 890 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.9066666666666667
#  Std 0.7056596598612931
# -- Generation 891 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.8266666666666667
#  Std 0.7593564526770168
# -- Generation 892 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.8966666666666667
#  Std 0.7567400845439307
# -- Generation 893 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.8566666666666667
#  Std 0.7677600898428857
# -- Generation 894 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.9
#  Std 0.7637626158259734
# -- Generation 895 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.7766666666666666
#  Std 0.7874783947653565
# -- Generation 896 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.8633333333333333
#  Std 0.7056832780283868
# -- Generation 897 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.8133333333333332
#  Std 0.7649546101276572
# -- Generation 898 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.8366666666666667
#  Std 0.718787559405111
# -- Generation 899 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.8666666666666667
#  Std 0.6896053621859065
# -- Generation 900 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.89
#  Std 0.7242697471706704
# -- Generation 901 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.8133333333333332
#  Std 0.751768285813891
# -- Generation 902 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.8633333333333333
#  Std 0.738007828925653
# -- Generation 903 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.8433333333333333
#  Std 0.77381450547847
# -- Generation 904 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.9766666666666666
#  Std 0.7806763449442771
# -- Generation 905 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.9
#  Std 0.7979139469057219
# -- Generation 906 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.9333333333333333
#  Std 0.7498147919467995
# -- Generation 907 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.84
#  Std 0.7622772898799142
# -- Generation 908 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.9766666666666666
#  Std 0.7720895169746979
# -- Generation 909 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.9033333333333333
#  Std 0.8168979264401535
# -- Generation 910 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 2.046666666666667
#  Std 0.7731896418228983
# -- Generation 911 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.9
#  Std 0.7979139469057219
# -- Generation 912 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.7833333333333334
#  Std 0.7679337355672181
# -- Generation 913 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.83
#  Std 0.7666594202556087
# -- Generation 914 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.8666666666666667
#  Std 0.7498147919467995
# -- Generation 915 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.9066666666666667
#  Std 0.7558365490560041
# -- Generation 916 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.9066666666666667
#  Std 0.7288956639251527
# -- Generation 917 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.9533333333333334
#  Std 0.7102738126165774
# -- Generation 918 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.9
#  Std 0.7461009761866466
# -- Generation 919 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.9266666666666667
#  Std 0.7032938377536249
# -- Generation 920 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.85
#  Std 0.7123903424387502
# -- Generation 921 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.8566666666666667
#  Std 0.754622790243944
# -- Generation 922 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.8766666666666667
#  Std 0.6593852355708979
# -- Generation 923 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.89
#  Std 0.6566835869224487
# -- Generation 924 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.9066666666666667
#  Std 0.6816320284598002
# -- Generation 925 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.9066666666666667
#  Std 0.6767241354906414
# -- Generation 926 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.92
#  Std 0.6220396557562334
# -- Generation 927 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.92
#  Std 0.6057502235520296
# -- Generation 928 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.93
#  Std 0.6621429855653032
# -- Generation 929 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.99
#  Std 0.6607319173966597
# -- Generation 930 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.98
#  Std 0.6528910067282798
# -- Generation 931 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.89
#  Std 0.676683086828687
# -- Generation 932 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.96
#  Std 0.6570641774844629
# -- Generation 933 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.9933333333333334
#  Std 0.6732673234970555
# -- Generation 934 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.9266666666666667
#  Std 0.6791825151525089
# -- Generation 935 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.9166666666666667
#  Std 0.6998015591739001
# -- Generation 936 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.8733333333333333
#  Std 0.7597952940686652
# -- Generation 937 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.9166666666666667
#  Std 0.7092640943651068
# -- Generation 938 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.9066666666666667
#  Std 0.7334545354386699
# -- Generation 939 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.87
#  Std 0.7301369734508723
# -- Generation 940 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.95
#  Std 0.7123903424387502
# -- Generation 941 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.9233333333333333
#  Std 0.7005632654435211
# -- Generation 942 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.8933333333333333
#  Std 0.6990151802516326
# -- Generation 943 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.8466666666666667
#  Std 0.6998730043530913
# -- Generation 944 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.9966666666666666
#  Std 0.66079917944528
# -- Generation 945 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.9366666666666668
#  Std 0.6826337882707598
# -- Generation 946 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.9333333333333333
#  Std 0.7498147919467995
# -- Generation 947 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.9166666666666667
#  Std 0.7232257984582372
# -- Generation 948 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.9333333333333333
#  Std 0.7133644853010902
# -- Generation 949 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.96
#  Std 0.696467276091754
# -- Generation 950 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.9866666666666666
#  Std 0.7255955408413765
# -- Generation 951 --
#  Evaluated 300 individuals
#  Min 1.0
#  Max 3.0
#  Avg 2.046666666666667
#  Std 0.7102738126165768
# -- Generation 952 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.95
#  Std 0.7216878364870323
# -- Generation 953 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.8133333333333332
#  Std 0.751768285813891
# -- Generation 954 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.9266666666666667
#  Std 0.6692948196090832
# -- Generation 955 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.8966666666666667
#  Std 0.7523223304467898
# -- Generation 956 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.8666666666666667
#  Std 0.7318166133366711
# -- Generation 957 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.9466666666666668
#  Std 0.6510162995057969
# -- Generation 958 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.91
#  Std 0.6597221637426873
# -- Generation 959 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.93
#  Std 0.6819824044651009
# -- Generation 960 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.87
#  Std 0.6581033353509156
# -- Generation 961 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.89
#  Std 0.7008803987367129
# -- Generation 962 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.9533333333333334
#  Std 0.6912468605514398
# -- Generation 963 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.88
#  Std 0.7341207893346526
# -- Generation 964 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.94
#  Std 0.7323933369440222
# -- Generation 965 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.9433333333333334
#  Std 0.7394517488578201
# -- Generation 966 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.8933333333333333
#  Std 0.7406903686576617
# -- Generation 967 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.9666666666666666
#  Std 0.711024300256718
# -- Generation 968 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.9633333333333334
#  Std 0.7361989465415504
# -- Generation 969 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.78
#  Std 0.7245228314783001
# -- Generation 970 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.8233333333333333
#  Std 0.7015142352242202
# -- Generation 971 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.8366666666666667
#  Std 0.6904024591175467
# -- Generation 972 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.9066666666666667
#  Std 0.6767241354906414
# -- Generation 973 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.8466666666666667
#  Std 0.7093345864650586
# -- Generation 974 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.8033333333333332
#  Std 0.7602558049031188
# -- Generation 975 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.88
#  Std 0.7476184410067304
# -- Generation 976 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.8933333333333333
#  Std 0.7316343956436775
# -- Generation 977 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.9566666666666668
#  Std 0.7034123178398914
# -- Generation 978 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.9366666666666668
#  Std 0.7434080679919713
# -- Generation 979 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.9066666666666667
#  Std 0.7646059260967194
# -- Generation 980 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.8566666666666667
#  Std 0.810013717304974
# -- Generation 981 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.9
#  Std 0.7810249675906653
# -- Generation 982 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.9233333333333333
#  Std 0.7984081384577414
# -- Generation 983 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.8933333333333333
#  Std 0.7451770855903238
# -- Generation 984 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.9166666666666667
#  Std 0.7851043808875916
# -- Generation 985 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.9166666666666667
#  Std 0.7893386824143077
# -- Generation 986 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.9533333333333334
#  Std 0.7817643862159208
# -- Generation 987 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.9133333333333333
#  Std 0.8036306503750478
# -- Generation 988 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.92
#  Std 0.7704544113703291
# -- Generation 989 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.8566666666666667
#  Std 0.7412526934558521
# -- Generation 990 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.9066666666666667
#  Std 0.7469642264228961
# -- Generation 991 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.83
#  Std 0.7622991538759568
# -- Generation 992 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.8233333333333333
#  Std 0.682243032617817
# -- Generation 993 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.9466666666666668
#  Std 0.7003491192890077
# -- Generation 994 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.98
#  Std 0.6973282345256546
# -- Generation 995 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.88
#  Std 0.7386474125047757
# -- Generation 996 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.8366666666666667
#  Std 0.7325677822260244
# -- Generation 997 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.9166666666666667
#  Std 0.7232257984582372
# -- Generation 998 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.9
#  Std 0.7371114795831994
# -- Generation 999 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.96
#  Std 0.6770524351924304
# -- Generation 1000 --
#  Evaluated 300 individuals
#  Min 0.0
#  Max 3.0
#  Avg 1.9366666666666668
#  Std 0.6971290331702504
# -- End of (successful) evolution --
# Best individual is olllo, (3.0,)

# %% [markdown]
# Now start to optimize the LSTM

# %% [markdown]
# ## Optimizing LSTM with Genetic Algorithm for Wind Forecasting

# %% [markdown]
# The necessary modules are imported. This time, we are using Keras to implement the LSTM model.

# %%
# !pip install bitstring
import numpy as np
import pandas as pd
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split as split

from keras.layers import LSTM, Input, Dense
from keras.models import Model

from deap import base, creator, tools, algorithms
from scipy.stats import bernoulli
from bitstring import BitArray

np.random.seed(1120)
# Out:
# Requirement already satisfied: bitstring in /usr/local/lib/python3.6/dist-packages (3.1.7)

# %% [markdown]
# The dataset we need for LSTM has to be time series data; we use the wind-power forecasting data from Kaggle (https://www.kaggle.com/c/GEF2012-wind-forecasting/data):

# %%
data = pd.read_csv('/content/drive/My Drive/optimization/train.csv')
data = np.reshape(np.array(data['wp1']),(len(data['wp1']),1))

train_data = data[0:17257]
test_data = data[17257:]

# %% [markdown]
# Define a function to prepare the dataset depending upon the chosen window_size.

# %%
def prepare_dataset(data, window_size):
    X, Y = np.empty((0,window_size)), np.empty((0))
    for i in range(len(data)-window_size-1):
        X = np.vstack([X,data[i:(i + window_size),0]])
        Y = np.append(Y,data[i + window_size,0])   
    X = np.reshape(X,(len(X),window_size,1))
    Y = np.reshape(Y,(len(Y),1))
    return X, Y

# %% [markdown]
# The train_evaluate function creates the LSTM network for a given individual and returns its RMSE value (fitness function).

# %%
def train_evaluate(ga_individual_solution):   
    # Decode GA solution to integer for window_size and num_units
    window_size_bits = BitArray(ga_individual_solution[0:6])
    num_units_bits = BitArray(ga_individual_solution[6:]) 
    window_size = window_size_bits.uint
    num_units = num_units_bits.uint
    print('\nWindow Size: ', window_size, ', Num of Units: ', num_units)
    
    # Return fitness score of 100 if window_size or num_unit is zero
    if window_size == 0 or num_units == 0:
        return 100, 
    
    # Segment the train_data based on new window_size; split into train and validation (80/20)
    X,Y = prepare_dataset(train_data,window_size)
    X_train, X_val, y_train, y_val = split(X, Y, test_size = 0.20, random_state = 1120)
    
    # Train LSTM model and predict on validation set
    inputs = Input(shape=(window_size,1))
    x = LSTM(num_units, input_shape=(window_size,1))(inputs)
    predictions = Dense(1, activation='linear')(x)
    model = Model(inputs=inputs, outputs=predictions)
    model.compile(optimizer='adam',loss='mean_squared_error')
    model.fit(X_train, y_train, epochs=5, batch_size=10,shuffle=True)
    y_pred = model.predict(X_val)
    
    # Calculate the RMSE score as fitness score for GA
    rmse = np.sqrt(mean_squared_error(y_val, y_pred))
    print('Validation RMSE: ', rmse,'\n')
    
    return rmse,

# %% [markdown]
# Next, we use DEAP tools to define Individual (again, since the chromosome is represented by a binary encoded string (10 bits), we use Bernoulli’s distribution), create the population, use ordered crossover, use mutShuffleIndexes mutation, and use the roulette wheel selection for selecting the parents.

# %%
population_size = 4
num_generations = 4
gene_length = 10

# As we are trying to minimize the RMSE score, that's why using -1.0. 
# In case, when you want to maximize accuracy for instance, use 1.0
creator.create('FitnessMax', base.Fitness, weights = (-1.0,))
creator.create('Individual', list , fitness = creator.FitnessMax)

toolbox = base.Toolbox()
toolbox.register('binary', bernoulli.rvs, 0.5)
toolbox.register('individual', tools.initRepeat, creator.Individual, toolbox.binary, n = gene_length)
toolbox.register('population', tools.initRepeat, list , toolbox.individual)

toolbox.register('mate', tools.cxOrdered)
toolbox.register('mutate', tools.mutShuffleIndexes, indpb = 0.6)
toolbox.register('select', tools.selRoulette)
toolbox.register('evaluate', train_evaluate)

population = toolbox.population(n = population_size)
r = algorithms.eaSimple(population, toolbox, cxpb = 0.4, mutpb = 0.1, ngen = num_generations, verbose = False)
# Out:
# /usr/local/lib/python3.6/dist-packages/deap/creator.py:141: RuntimeWarning: A class named 'FitnessMax' has already been created and it will be overwritten. Consider deleting previous creation of that class or rename it.
#   RuntimeWarning)
# /usr/local/lib/python3.6/dist-packages/deap/creator.py:141: RuntimeWarning: A class named 'Individual' has already been created and it will be overwritten. Consider deleting previous creation of that class or rename it.
#   RuntimeWarning)
# Window Size:  36 , Num of Units:  2
# Epoch 1/5
# 1378/1378 [==============================] - 5s 4ms/step - loss: 0.0142
# Epoch 2/5
# 1378/1378 [==============================] - 5s 4ms/step - loss: 0.0080
# Epoch 3/5
# 1378/1378 [==============================] - 5s 4ms/step - loss: 0.0067
# Epoch 4/5
# 1378/1378 [==============================] - 5s 4ms/step - loss: 0.0061
# Epoch 5/5
# 1378/1378 [==============================] - 5s 4ms/step - loss: 0.0059
# Validation RMSE:  0.07657147567814025
#
#
# Window Size:  56 , Num of Units:  8
# Epoch 1/5
# 1376/1376 [==============================] - 5s 4ms/step - loss: 0.0166
# Epoch 2/5
# 1376/1376 [==============================] - 5s 4ms/step - loss: 0.0066
# Epoch 3/5
# 1376/1376 [==============================] - 5s 4ms/step - loss: 0.0059
# Epoch 4/5
# 1376/1376 [==============================] - 5s 4ms/step - loss: 0.0058
# Epoch 5/5
# 1376/1376 [==============================] - 5s 4ms/step - loss: 0.0058
# Validation RMSE:  0.07460835955711853
#
#
# Window Size:  60 , Num of Units:  9
# Epoch 1/5
# 1376/1376 [==============================] - 6s 4ms/step - loss: 0.0128
# Epoch 2/5
# 1376/1376 [==============================] - 6s 4ms/step - loss: 0.0065
# Epoch 3/5
# 1376/1376 [==============================] - 6s 4ms/step - loss: 0.0058
# Epoch 4/5
# 1376/1376 [==============================] - 6s 4ms/step - loss: 0.0057
# Epoch 5/5
# 1376/1376 [==============================] - 6s 4ms/step - loss: 0.0057
# Validation RMSE:  0.07706023201227538
#
#
# Window Size:  49 , Num of Units:  9
# Epoch 1/5
# 1377/1377 [==============================] - 6s 4ms/step - loss: 0.0180
# Epoch 2/5
# 1377/1377 [==============================] - 6s 4ms/step - loss: 0.0066
# Epoch 3/5
# 1377/1377 [==============================] - 5s 4ms/step - loss: 0.0059
# Epoch 4/5
# 1377/1377 [==============================] - 5s 4ms/step - loss: 0.0058
# Epoch 5/5
# 1377/1377 [==============================] - 5s 4ms/step - loss: 0.0058
# Validation RMSE:  0.07401749818139357
#
#
# Window Size:  19 , Num of Units:  10
# Epoch 1/5
# 1379/1379 [==============================] - 5s 3ms/step - loss: 0.0118
# Epoch 2/5
# 1379/1379 [==============================] - 5s 3ms/step - loss: 0.0064
# Epoch 3/5
# 1379/1379 [==============================] - 5s 3ms/step - loss: 0.0058
# Epoch 4/5
# 1379/1379 [==============================] - 5s 4ms/step - loss: 0.0057
# Epoch 5/5
# 1379/1379 [==============================] - 5s 4ms/step - loss: 0.0057
# Validation RMSE:  0.07626664421135554
#
#
# Window Size:  33 , Num of Units:  8
# Epoch 1/5
# 1378/1378 [==============================] - 5s 4ms/step - loss: 0.0098
# Epoch 2/5
# 1378/1378 [==============================] - 5s 4ms/step - loss: 0.0061
# Epoch 3/5
# 1378/1378 [==============================] - 5s 4ms/step - loss: 0.0057
# Epoch 4/5
# 1378/1378 [==============================] - 5s 4ms/step - loss: 0.0057
# Epoch 5/5
# 1378/1378 [==============================] - 5s 3ms/step - loss: 0.0057
# Validation RMSE:  0.0756925384920299
#
#
# Window Size:  60 , Num of Units:  10
# Epoch 1/5
# 1376/1376 [==============================] - 6s 4ms/step - loss: 0.0130
# Epoch 2/5
# 1376/1376 [==============================] - 6s 4ms/step - loss: 0.0063
# Epoch 3/5
# 1376/1376 [==============================] - 6s 4ms/step - loss: 0.0059
# Epoch 4/5
# 1376/1376 [==============================] - 6s 4ms/step - loss: 0.0058
# Epoch 5/5
# 1376/1376 [==============================] - 6s 4ms/step - loss: 0.0058
# Validation RMSE:  0.07514441968159848
#
#
# Window Size:  41 , Num of Units:  9
# Epoch 1/5
# 1378/1378 [==============================] - 6s 4ms/step - loss: 0.0114
# Epoch 2/5
# 1378/1378 [==============================] - 5s 4ms/step - loss: 0.0059
# Epoch 3/5
# 1378/1378 [==============================] - 5s 4ms/step - loss: 0.0055
# Epoch 4/5
# 1378/1378 [==============================] - 5s 4ms/step - loss: 0.0055
# Epoch 5/5
# 1378/1378 [==============================] - 5s 4ms/step - loss: 0.0055
# Validation RMSE:  0.08147052731973314
#
#
# Window Size:  57 , Num of Units:  8
# Epoch 1/5
# 1376/1376 [==============================] - 6s 4ms/step - loss: 0.0198
# Epoch 2/5
# 1376/1376 [==============================] - 6s 4ms/step - loss: 0.0064
# Epoch 3/5
# 1376/1376 [==============================] - 6s 4ms/step - loss: 0.0057
# Epoch 4/5
# 1376/1376 [==============================] - 6s 4ms/step - loss: 0.0057
# Epoch 5/5
# 1376/1376 [==============================] - 6s 4ms/step - loss: 0.0057
# Validation RMSE:  0.07616143889335555
#
#
# Window Size:  44 , Num of Units:  11
# Epoch 1/5
# 1377/1377 [==============================] - 6s 4ms/step - loss: 0.0100
# Epoch 2/5
# 1377/1377 [==============================] - 5s 4ms/step - loss: 0.0061
# Epoch 3/5
# 1377/1377 [==============================] - 6s 4ms/step - loss: 0.0058
# Epoch 4/5
# 1377/1377 [==============================] - 6s 4ms/step - loss: 0.0058
# Epoch 5/5
# 1377/1377 [==============================] - 6s 4ms/step - loss: 0.0058
# Validation RMSE:  0.07387889416927318
#
#
# Window Size:  58 , Num of Units:  10
# Epoch 1/5
# 1376/1376 [==============================] - 6s 4ms/step - loss: 0.0154
# Epoch 2/5
# 1376/1376 [==============================] - 6s 4ms/step - loss: 0.0067
# Epoch 3/5
# 1376/1376 [==============================] - 6s 4ms/step - loss: 0.0060
# Epoch 4/5
# 1376/1376 [==============================] - 6s 4ms/step - loss: 0.0058
# Epoch 5/5
# 1376/1376 [==============================] - 6s 4ms/step - loss: 0.0058
# Validation RMSE:  0.07326527449985087

# %% [markdown]
# Print top N solutions - (1st only, for now)

# %%
best_individuals = tools.selBest(population,k = 1)
best_window_size = None
best_num_units = None

for bi in best_individuals:
    window_size_bits = BitArray(bi[0:6])
    num_units_bits = BitArray(bi[6:]) 
    best_window_size = window_size_bits.uint
    best_num_units = num_units_bits.uint
    print('\nWindow Size: ', best_window_size, ', Num of Units: ', best_num_units)
# Out:
# Window Size:  58 , Num of Units:  10

# %% [markdown]
# Train the model using best configuration on complete training set and make predictions on the test set.

# %%
X_train,y_train = prepare_dataset(train_data,best_window_size)
X_test, y_test = prepare_dataset(test_data,best_window_size)

inputs = Input(shape=(best_window_size,1))
x = LSTM(best_num_units, input_shape=(best_window_size,1))(inputs)
predictions = Dense(1, activation='linear')(x)
model = Model(inputs = inputs, outputs = predictions)
model.compile(optimizer='adam',loss='mean_squared_error')
model.fit(X_train, y_train, epochs=5, batch_size=10,shuffle=True)
y_pred = model.predict(X_test)

rmse = np.sqrt(mean_squared_error(y_test, y_pred))
print('Test RMSE: ', rmse)
# Out:
# Epoch 1/5
# 1720/1720 [==============================] - 8s 4ms/step - loss: 0.0124
# Epoch 2/5
# 1720/1720 [==============================] - 7s 4ms/step - loss: 0.0061
# Epoch 3/5
# 1720/1720 [==============================] - 8s 4ms/step - loss: 0.0059
# Epoch 4/5
# 1720/1720 [==============================] - 7s 4ms/step - loss: 0.0058
# Epoch 5/5
# 1720/1720 [==============================] - 7s 4ms/step - loss: 0.0058
# Test RMSE:  0.09254902559947434
